# %%
# =======================================================
# Imports
# =======================================================

import pandas as pd
from vega_datasets import data

# %%
# =======================================================
# Datasets
# =======================================================
df_pessoa_acidentes_2007 = pd.read_csv('../PRF/por_pessoa/acidentes2007.csv', sep=',', encoding="ISO-8859-1")
df_pessoa_acidentes_2008 = pd.read_csv('../PRF/por_pessoa/acidentes2008.csv', sep=',', encoding="ISO-8859-1")
df_pessoa_acidentes_2009 = pd.read_csv('../PRF/por_pessoa/acidentes2009.csv', sep=',', encoding="ISO-8859-1")
df_pessoa_acidentes_2010 = pd.read_csv('../PRF/por_pessoa/acidentes2010.csv', sep=',', encoding="ISO-8859-1")
df_pessoa_acidentes_2011 = pd.read_csv('../PRF/por_pessoa/acidentes2011.csv', sep=',', encoding="ISO-8859-1")
df_pessoa_acidentes_2012 = pd.read_csv('../PRF/por_pessoa/acidentes2012.csv', sep=',', encoding="ISO-8859-1")
df_pessoa_acidentes_2013 = pd.read_csv('../PRF/por_pessoa/acidentes2013.csv', sep=',', encoding="ISO-8859-1")
df_pessoa_acidentes_2014 = pd.read_csv('../PRF/por_pessoa/acidentes2014.csv', sep=',', encoding="ISO-8859-1")
df_pessoa_acidentes_2015 = pd.read_csv('../PRF/por_pessoa/acidentes2015.csv', sep=',', encoding="ISO-8859-1")
df_pessoa_acidentes_2016 = pd.read_csv('../PRF/por_pessoa/acidentes2016.csv', sep=';', encoding="ISO-8859-1")
df_pessoa_acidentes_2017 = pd.read_csv('../PRF/por_pessoa/acidentes2017.csv', sep=';', encoding="ISO-8859-1")
df_pessoa_acidentes_2018 = pd.read_csv('../PRF/por_pessoa/acidentes2018.csv', sep=';', encoding="ISO-8859-1")
df_pessoa_acidentes_2019 = pd.read_csv('../PRF/por_pessoa/acidentes2019.csv', sep=';', encoding="ISO-8859-1")
df_pessoa_acidentes_2020 = pd.read_csv('../PRF/por_pessoa/acidentes2020.csv', sep=';', encoding="ISO-8859-1")
df_pessoa_acidentes_2021 = pd.read_csv('../PRF/por_pessoa/acidentes2021.csv', sep=';', encoding="ISO-8859-1")
df_pessoa_acidentes_2022 = pd.read_csv('../PRF/por_pessoa/acidentes2022.csv', sep=';', encoding="ISO-8859-1")
df_pessoa_acidentes_2023 = pd.read_csv('../PRF/por_pessoa/acidentes2023.csv', sep=';', encoding="ISO-8859-1")
df_pessoa_acidentes_2024 = pd.read_csv('../PRF/por_pessoa/acidentes2024.csv', sep=';', encoding="ISO-8859-1")
# Out:
# /tmp/ipykernel_5179/3339992157.py:4: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_pessoa_acidentes_2007 = pd.read_csv('../PRF/por_pessoa/acidentes2007.csv', sep=',', encoding="ISO-8859-1")
# /tmp/ipykernel_5179/3339992157.py:5: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_pessoa_acidentes_2008 = pd.read_csv('../PRF/por_pessoa/acidentes2008.csv', sep=',', encoding="ISO-8859-1")
# /tmp/ipykernel_5179/3339992157.py:9: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_pessoa_acidentes_2012 = pd.read_csv('../PRF/por_pessoa/acidentes2012.csv', sep=',', encoding="ISO-8859-1")
# /tmp/ipykernel_5179/3339992157.py:14: DtypeWarning: Columns (22,23,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_pessoa_acidentes_2017 = pd.read_csv('../PRF/por_pessoa/acidentes2017.csv', sep=';', encoding="ISO-8859-1")

# %%
# =======================================================
# Datasets por ocorrencias
# =======================================================
df_por_ocorrencia_2007 = pd.read_csv('../PRF/por_ocorrencia/datatran2007.csv', sep=';', encoding="ISO-8859-1")
df_por_ocorrencia_2008 = pd.read_csv('../PRF/por_ocorrencia/datatran2008.csv', sep=';', encoding="ISO-8859-1")
df_por_ocorrencia_2009 = pd.read_csv('../PRF/por_ocorrencia/datatran2009.csv', sep=';', encoding="ISO-8859-1")
df_por_ocorrencia_2010 = pd.read_csv('../PRF/por_ocorrencia/datatran2010.csv', sep=';', encoding="ISO-8859-1")
df_por_ocorrencia_2011 = pd.read_csv('../PRF/por_ocorrencia/datatran2011.csv', sep=';', encoding="ISO-8859-1")
df_por_ocorrencia_2012 = pd.read_csv('../PRF/por_ocorrencia/datatran2012.csv', sep=';', encoding="ISO-8859-1")
df_por_ocorrencia_2013 = pd.read_csv('../PRF/por_ocorrencia/datatran2013.csv', sep=';', encoding="ISO-8859-1")
df_por_ocorrencia_2014 = pd.read_csv('../PRF/por_ocorrencia/datatran2014.csv', sep=';', encoding="ISO-8859-1")
df_por_ocorrencia_2015 = pd.read_csv('../PRF/por_ocorrencia/datatran2015.csv', sep=';', encoding="ISO-8859-1")
df_por_ocorrencia_2016 = pd.read_csv('../PRF/por_ocorrencia/datatran2016.csv', sep=';', encoding="ISO-8859-1")
df_por_ocorrencia_2017 = pd.read_csv('../PRF/por_ocorrencia/datatran2017.csv', sep=';', encoding="ISO-8859-1")
df_por_ocorrencia_2018 = pd.read_csv('../PRF/por_ocorrencia/datatran2018.csv', sep=';', encoding="ISO-8859-1")
df_por_ocorrencia_2019 = pd.read_csv('../PRF/por_ocorrencia/datatran2019.csv', sep=';', encoding="ISO-8859-1")
df_por_ocorrencia_2020 = pd.read_csv('../PRF/por_ocorrencia/datatran2020.csv', sep=';', encoding="ISO-8859-1")
df_por_ocorrencia_2021 = pd.read_csv('../PRF/por_ocorrencia/datatran2021.csv', sep=';', encoding="ISO-8859-1")
df_por_ocorrencia_2022 = pd.read_csv('../PRF/por_ocorrencia/datatran2022.csv', sep=';', encoding="ISO-8859-1")
df_por_ocorrencia_2023 = pd.read_csv('../PRF/por_ocorrencia/datatran2023.csv', sep=';', encoding="ISO-8859-1")
df_por_ocorrencia_2024 = pd.read_csv('../PRF/por_ocorrencia/datatran2024.csv', sep=';', encoding="ISO-8859-1")
# Out:
# /tmp/ipykernel_6166/1112222753.py:4: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_por_ocorrencia_2007 = pd.read_csv('../PRF/por_ocorrencia/datatran2007.csv', sep=';', encoding="ISO-8859-1")
# /tmp/ipykernel_6166/1112222753.py:5: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_por_ocorrencia_2008 = pd.read_csv('../PRF/por_ocorrencia/datatran2008.csv', sep=';', encoding="ISO-8859-1")
# /tmp/ipykernel_6166/1112222753.py:9: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_por_ocorrencia_2012 = pd.read_csv('../PRF/por_ocorrencia/datatran2012.csv', sep=';', encoding="ISO-8859-1")

# %%
df_2024 = pd.read_csv('geo/acidentes_localizacao_processado_2024.csv', sep=';', encoding="ISO-8859-1")
df_2024
# Out:
#        Unnamed: 0 data_inversa  uf           municipio   br     km   latitude  \
# 0               0   2024-01-01  ES  CONCEICAO DA BARRA  101     38 -18.482610
# 1               1   2024-01-01  PI            PIRIPIRI  343    185  -4.296033
# 2               2   2024-01-01  BA             BREJOES  116    578 -13.071583
# 3               3   2024-01-01  SE    MALHADA DOS BOIS  101     18 -10.356019
# 4               4   2024-01-01  MT        RONDONOPOLIS  364    240 -16.179141
# ...           ...          ...  ..                 ...  ...    ...        ...
# 27248       27248   2024-07-07  SC               LAGES  282  210,4 -27.779277
# 27249       27249   2024-08-31  BA                CATU  110    379 -12.411964
# 27250       27250   2024-07-21  ES       MIMOSO DO SUL  101  445,5 -21.110463
# 27251       27251   2024-08-20  MG     AGUAS VERMELHAS  116   13,6 -15.804386
# 27252       27252   2024-06-01  MG           ALPERCATA  116    422 -18.952870
#
#        longitude  acidentes
# 0     -39.923790          3
# 1     -41.767327          2
# 2     -39.961111          9
# 3     -36.905522          3
# 4     -54.789053         10
# ...          ...        ...
# 27248 -50.235691          7
# 27249 -38.436857          1
# 27250 -41.263511          3
# 27251 -41.359894          1
# 27252 -41.956825          1
#
# [27253 rows x 9 columns]

# %%
df_br_uf = df_2024[(df_2024['br'] == 101) & (df_2024['uf'] == 'PE')]
df_br_uf
# Out:
#        Unnamed: 0 data_inversa  uf                municipio   br    km  \
# 43             43   2024-01-02  PE                 IGARASSU  101    46
# 46             46   2024-01-02  PE                 PALMARES  101   198
# 159           159   2024-01-05  PE                   GOIANA  101     4
# 261           261   2024-01-08  PE  JABOATAO DOS GUARARAPES  101    83
# 463           463   2024-01-13  PE                   RECIFE  101  65,5
# ...           ...          ...  ..                      ...  ...   ...
# 26996       26996   2024-08-29  PE                 PAULISTA  101    54
# 27080       27080   2024-08-30  PE                   RECIFE  101  72,6
# 27122       27122   2024-08-31  PE                   RECIFE  101    68
# 27200       27200   2024-08-22  PE                 PALMARES  101   180
# 27244       27244   2024-06-13  PE                   ESCADA  101   130
#
#        latitude  longitude  acidentes
# 43    -7.873478 -34.905957          4
# 46    -8.761488 -35.606362          1
# 159   -7.533512 -34.991547          5
# 261   -8.175172 -34.942642         12
# 463   -8.024786 -34.942766         20
# ...         ...        ...        ...
# 26996 -7.945889 -34.904766          2
# 27080 -8.090625 -34.946855          2
# 27122 -8.050112 -34.946019          6
# 27200 -8.635238 -35.560932          2
# 27244 -8.392345 -35.257055          2
#
# [344 rows x 9 columns]

# %%
df2 = df_2024[(df_2024['br'] == 101)]
lista_ufs = df2['uf'].unique()
lista_ufs
# Out:
# array(['ES', 'SE', 'BA', 'RS', 'PB', 'SC', 'PE', 'RJ', 'AL', 'RN', 'SP'],
#       dtype=object)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Criando um array aleatório de 1 a 9 com repetições
arr = np.random.choice(np.arange(1, 9), size=81).reshape(9, 9)

print(arr)
# Out:
# [[1 3 3 2 2 1 7 8 4]
#  [3 7 6 5 3 6 5 1 1]
#  [7 2 5 7 8 7 1 6 6]
#  [3 3 6 2 3 2 6 7 3]
#  [1 5 6 3 8 4 4 7 7]
#  [5 4 4 1 3 1 6 1 4]
#  [4 6 3 8 1 5 7 1 1]
#  [5 4 1 2 4 6 7 1 5]
#  [6 2 2 5 3 1 2 4 2]]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Criar um array 9x9 com zeros
array = np.zeros((9, 9), dtype=int)

# Coluna a ser preenchida (começando em 0)
coluna_a_preencher = 3

# Preencher a coluna com números de 1 a 9
array[:, coluna_a_preencher] = np.arange(1, 10)

# Criar uma máscara para destacar as bordas
mask = np.zeros_like(array)
mask[0, :] = 1  # Primeira linha
mask[-1, :] = 1  # Última linha
mask[:, 0] = 1  # Primeira coluna
mask[:, -1] = 1  # Última coluna

# Aplicar a máscara para destacar as bordas
array[mask == 1] = 255

# Visualizar o array como imagem
plt.imshow(array, cmap='gray')
plt.show()

# Salvar a imagem
plt.imsave('imagem_com_bordas.png', array, cmap='gray')

# %%
import altair as alt
from vega_datasets import data

source = data.seattle_weather()

alt.Chart(source, title="Daily Max Temperatures (C) in Seattle, WA").mark_rect().encode(
    alt.X("date(date):O").title("Day").axis(format="%e", labelAngle=0),
    alt.Y("month(date):O").title("Month"),
    alt.Color("max(temp_max)").title(None),
    tooltip=[
        alt.Tooltip("monthdate(date)", title="Date"),
        alt.Tooltip("max(temp_max)", title="Max Temp"),
    ],
).configure_view(
    step=13,
    strokeWidth=0
).configure_axis(
    domain=False
)
# Out:
# alt.Chart(...)

# %%
source = data.seattle_weather()
source
# Out:
#            date  precipitation  temp_max  temp_min  wind  weather
# 0    2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1    2012-01-02           10.9      10.6       2.8   4.5     rain
# 2    2012-01-03            0.8      11.7       7.2   2.3     rain
# 3    2012-01-04           20.3      12.2       5.6   4.7     rain
# 4    2012-01-05            1.3       8.9       2.8   6.1     rain
# ...         ...            ...       ...       ...   ...      ...
# 1456 2015-12-27            8.6       4.4       1.7   2.9      fog
# 1457 2015-12-28            1.5       5.0       1.7   1.3      fog
# 1458 2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459 2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460 2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
df_acidentes_geral_por_uf_10 = pd.read_csv('datasets/gerais/acidentes_geral_por_uf_10.csv', sep=',', encoding="UTF-8") 
df_acidentes_geral_por_uf_10

filtrado = df_acidentes_geral_por_uf_10[(df_acidentes_geral_por_uf_10['ano'] == 2024)]
filtrado
# Out:
#      uf    qtd   ano
# 17   MG  16708  2024
# 35   SC  13877  2024
# 53   RJ  10190  2024
# 71   RS   9188  2024
# 89   SP   7893  2024
# 107  BA   8123  2024
# 125  PR  13624  2024
# 143  ES   4038  2024
# 161  GO   5929  2024
# 179  PE   5358  2024

# %%
df_acidentes_geral_por_uf_10 = pd.read_csv('datasets/gerais/acidentes_geral_por_uf_10.csv', sep=',', encoding="UTF-8") 
df_acidentes_geral_por_uf_10

#uf,qtd,ano

grafico = alt.Chart(filtrado, title="Mapa de Calor - UF").mark_rect().encode(
    alt.X("ano:Q").title("Ano").axis(format="%e", labelAngle=0),
    alt.Y("uf:N").title("UF"),
    alt.Color("max(qtd)").title(None),
    tooltip=[
        alt.Tooltip("ano", title="Ano"),
        alt.Tooltip("max(qtd)", title="Qtd de Acidentes"),
    ],
).configure_view(
    step=13,
    strokeWidth=0
).configure_axis(
    domain=False
)
grafico
# Out:
# alt.Chart(...)

# %%
# Cria o gráfico de calor
heatmap = alt.Chart(df_acidentes_geral_por_uf_10).mark_rect().encode(
    x=alt.X('ano:O', title=None, axis=alt.Axis(orient='top')),  # Define a orientação do eixo x como 'top'
    y=alt.Y('uf:N', title=None),
    color=alt.Color('qtd:Q', scale=alt.Scale(scheme='yellowgreenblue')),    
)

# Adiciona o texto dentro de cada célula com o valor real e ajusta a cor do texto
text = alt.Chart(df_acidentes_geral_por_uf_10).mark_text(baseline='middle', fontSize=10).encode(
    x='ano:O',
    y='uf:O',
    text=alt.Text('qtd:Q', format='.0f'),
)

# Combina o gráfico de calor com o texto
heatmap_with_text = (heatmap + text).properties(
    width=800,
    height=600,
    title=f'Mapa de Calor por Classificação x Envolvidos (2024)'
)

heatmap_with_text
# Out:
# alt.LayerChart(...)

# %%
from vega_datasets import data

cars = data.cars.url

selection = alt.selection_point(fields=['Origin'])
color = alt.condition(
    selection,
    alt.Color('Origin:N').legend(None),
    alt.value('lightgray')
)

scatter = alt.Chart(cars).mark_point().encode(
    x='Horsepower:Q',
    y='Miles_per_Gallon:Q',
    color=color,
    tooltip='Name:N'
)

legend = alt.Chart(cars).mark_point().encode(
    alt.Y('Origin:N').axis(orient='right'),
    color=color
).add_params(
    selection
)

scatter | legend
# Out:
# alt.HConcatChart(...)

# %%
grafico1 = alt.Chart(df_acidentes_geral_por_uf_10).mark_line(point=True).encode(
    x=alt.X('ano:O', title='Ano'),
    y=alt.Y("rank:O", title='Posição do Ranking'),
    color=alt.Color("uf:N", title='UF') 
).transform_window(
    rank="rank()",
    sort=[alt.SortField("qtd", order="descending")],
    groupby=["ano"]
).properties(
    title="Ranking das 10 UFs com mais Acidentes (2007 a 2024)",
    width=800,
    height=600,
)

grafico1
# Out:
# alt.Chart(...)

# %%
import altair as alt
from vega_datasets import data

source = data.cars()
source.head()
# Out:
#                         Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0  chevrolet chevelle malibu              18.0          8         307.0
# 1          buick skylark 320              15.0          8         350.0
# 2         plymouth satellite              18.0          8         318.0
# 3              amc rebel sst              16.0          8         304.0
# 4                ford torino              17.0          8         302.0
#
#    Horsepower  Weight_in_lbs  Acceleration       Year Origin
# 0       130.0           3504          12.0 1970-01-01    USA
# 1       165.0           3693          11.5 1970-01-01    USA
# 2       150.0           3436          11.0 1970-01-01    USA
# 3       150.0           3433          12.0 1970-01-01    USA
# 4       140.0           3449          10.5 1970-01-01    USA

# %%
import altair as alt
from vega_datasets import data

source = data.cars()

alt.Chart(source).mark_circle().encode(
    alt.X(alt.repeat("column"), type='quantitative'),
    alt.Y(alt.repeat("row"), type='quantitative'),
    color='Origin:N'
).properties(
    width=150,
    height=150
).repeat(
    row=['Horsepower', 'Acceleration', 'Miles_per_Gallon'],
    column=['Miles_per_Gallon', 'Acceleration', 'Horsepower']
).interactive()
# Out:
# alt.RepeatChart(...)
